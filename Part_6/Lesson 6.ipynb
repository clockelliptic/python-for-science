# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Lecture-6" data-toc-modified-id="Lecture-6-1">Lecture 6</a></span><ul class="toc-item"><li><span><a href="#Matplotlib" data-toc-modified-id="Matplotlib-1.1">Matplotlib</a></span></li><li><span><a href="#6.1-Matplotlib-Introduction" data-toc-modified-id="6.1-Matplotlib-Introduction-1.2">6.1 Matplotlib Introduction</a></span><ul class="toc-item"><li><span><a href="#6.1.1-What-is-Matplotlib?" data-toc-modified-id="6.1.1-What-is-Matplotlib?-1.2.1">6.1.1 What is Matplotlib?</a></span></li><li><span><a href="#6.1.2-Matplotlib-Basics" data-toc-modified-id="6.1.2-Matplotlib-Basics-1.2.2">6.1.2 Matplotlib Basics</a></span></li><li><span><a href="#6.1.2.1-Creating-charts" data-toc-modified-id="6.1.2.1-Creating-charts-1.2.3">6.1.2.1 Creating charts</a></span></li><li><span><a href="#Data-Types" data-toc-modified-id="Data-Types-1.2.4">Data Types</a></span><ul class="toc-item"><li><span><a href="#Part-1-(Data-Types-for-Creating-Charts-in-Matplotlib)" data-toc-modified-id="Part-1-(Data-Types-for-Creating-Charts-in-Matplotlib)-1.2.4.1">Part 1 (Data Types for Creating Charts in Matplotlib)</a></span><ul class="toc-item"><li><span><a href="#Example-1.1-(Creating-a-line-chart-from-a-list)" data-toc-modified-id="Example-1.1-(Creating-a-line-chart-from-a-list)-1.2.4.1.1">Example 1.1 (Creating a line chart from a list)</a></span></li><li><span><a href="#Example-1.2-(Creating-a-line-chart-from-a-Numpy-array)" data-toc-modified-id="Example-1.2-(Creating-a-line-chart-from-a-Numpy-array)-1.2.4.1.2">Example 1.2 (Creating a line chart from a Numpy array)</a></span></li><li><span><a href="#Example-1.3-(Creating-a-line-chart-from-a-Pandas-Series)" data-toc-modified-id="Example-1.3-(Creating-a-line-chart-from-a-Pandas-Series)-1.2.4.1.3">Example 1.3 (Creating a line chart from a Pandas Series)</a></span></li><li><span><a href="#Example-1.4-(Creating-a-line-chart-from-a-Pandas-DataFrame)" data-toc-modified-id="Example-1.4-(Creating-a-line-chart-from-a-Pandas-DataFrame)-1.2.4.1.4">Example 1.4 (Creating a line chart from a Pandas DataFrame)</a></span></li></ul></li></ul></li><li><span><a href="#6.1.2.2-Fomatting-charts" data-toc-modified-id="6.1.2.2-Fomatting-charts-1.2.5">6.1.2.2 Fomatting charts</a></span><ul class="toc-item"><li><span><a href="#Part-1-(Adding-Titles)" data-toc-modified-id="Part-1-(Adding-Titles)-1.2.5.1">Part 1 (Adding Titles)</a></span><ul class="toc-item"><li><span><a href="#Example-1.1" data-toc-modified-id="Example-1.1-1.2.5.1.1">Example 1.1</a></span></li></ul></li><li><span><a href="#Part-2-(Adding-X-Y-Labels)" data-toc-modified-id="Part-2-(Adding-X-Y-Labels)-1.2.5.2">Part 2 (Adding X-Y Labels)</a></span><ul class="toc-item"><li><span><a href="#Example-2.1" data-toc-modified-id="Example-2.1-1.2.5.2.1">Example 2.1</a></span></li><li><span><a href="#Problem-1" data-toc-modified-id="Problem-1-1.2.5.2.2">Problem 1</a></span></li><li><span><a href="#Problem-2" data-toc-modified-id="Problem-2-1.2.5.2.3">Problem 2</a></span></li></ul></li><li><span><a href="#Part-3-(Gridlines)" data-toc-modified-id="Part-3-(Gridlines)-1.2.5.3">Part 3 (Gridlines)</a></span><ul class="toc-item"><li><span><a href="#Example-3.1" data-toc-modified-id="Example-3.1-1.2.5.3.1">Example 3.1</a></span></li><li><span><a href="#Example-3.2" data-toc-modified-id="Example-3.2-1.2.5.3.2">Example 3.2</a></span></li><li><span><a href="#Example-3.3" data-toc-modified-id="Example-3.3-1.2.5.3.3">Example 3.3</a></span></li><li><span><a href="#Problem-3" data-toc-modified-id="Problem-3-1.2.5.3.4">Problem 3</a></span></li></ul></li><li><span><a href="#Part-4-(Multiple-Lines)" data-toc-modified-id="Part-4-(Multiple-Lines)-1.2.5.4">Part 4 (Multiple Lines)</a></span><ul class="toc-item"><li><span><a href="#Example-4.1" data-toc-modified-id="Example-4.1-1.2.5.4.1">Example 4.1</a></span></li></ul></li><li><span><a href="#Part-5-(Legends)" data-toc-modified-id="Part-5-(Legends)-1.2.5.5">Part 5 (Legends)</a></span><ul class="toc-item"><li><span><a href="#Example-5.1" data-toc-modified-id="Example-5.1-1.2.5.5.1">Example 5.1</a></span></li></ul></li><li><span><a href="#Part-6-(Color)" data-toc-modified-id="Part-6-(Color)-1.2.5.6">Part 6 (Color)</a></span><ul class="toc-item"><li><span><a href="#Example-6.1:-Color-with-alias" data-toc-modified-id="Example-6.1:-Color-with-alias-1.2.5.6.1">Example 6.1: Color with alias</a></span></li><li><span><a href="#Example-6.2:-Color-with-Name" data-toc-modified-id="Example-6.2:-Color-with-Name-1.2.5.6.2">Example 6.2: Color with Name</a></span></li><li><span><a href="#Example-6.3:-Color-with-RGB-Hexadecimal" data-toc-modified-id="Example-6.3:-Color-with-RGB-Hexadecimal-1.2.5.6.3">Example 6.3: Color with RGB Hexadecimal</a></span></li></ul></li><li><span><a href="#Part-7-(Line-Width)" data-toc-modified-id="Part-7-(Line-Width)-1.2.5.7">Part 7 (Line Width)</a></span><ul class="toc-item"><li><span><a href="#Example-7.1" data-toc-modified-id="Example-7.1-1.2.5.7.1">Example 7.1</a></span></li></ul></li><li><span><a href="#Part-8-(Line-Style)" data-toc-modified-id="Part-8-(Line-Style)-1.2.5.8">Part 8 (Line Style)</a></span><ul class="toc-item"><li><span><a href="#Example-8.1" data-toc-modified-id="Example-8.1-1.2.5.8.1">Example 8.1</a></span></li><li><span><a href="#Problem-4" data-toc-modified-id="Problem-4-1.2.5.8.2">Problem 4</a></span></li></ul></li></ul></li><li><span><a href="#6.1.2.3-Types-of-Charts" data-toc-modified-id="6.1.2.3-Types-of-Charts-1.2.6">6.1.2.3 Types of Charts</a></span><ul class="toc-item"><li><span><a href="#Part-1-(Line-Charts)" data-toc-modified-id="Part-1-(Line-Charts)-1.2.6.1">Part 1 (Line Charts)</a></span><ul class="toc-item"><li><span><a href="#Example-1.1" data-toc-modified-id="Example-1.1-1.2.6.1.1">Example 1.1</a></span></li></ul></li><li><span><a href="#Part-2-(Bar-Chart)" data-toc-modified-id="Part-2-(Bar-Chart)-1.2.6.2">Part 2 (Bar Chart)</a></span><ul class="toc-item"><li><span><a href="#Example-2.1" data-toc-modified-id="Example-2.1-1.2.6.2.1">Example 2.1</a></span></li></ul></li><li><span><a href="#Part-3-(Error-Bars)" data-toc-modified-id="Part-3-(Error-Bars)-1.2.6.3">Part 3 (Error Bars)</a></span><ul class="toc-item"><li><span><a href="#Example-3.1" data-toc-modified-id="Example-3.1-1.2.6.3.1">Example 3.1</a></span></li></ul></li><li><span><a href="#Part-4-(Scatter-Plot)" data-toc-modified-id="Part-4-(Scatter-Plot)-1.2.6.4">Part 4 (Scatter Plot)</a></span><ul class="toc-item"><li><span><a href="#Example-4.1" data-toc-modified-id="Example-4.1-1.2.6.4.1">Example 4.1</a></span></li><li><span><a href="#Example-4.2" data-toc-modified-id="Example-4.2-1.2.6.4.2">Example 4.2</a></span></li><li><span><a href="#Example-4.3" data-toc-modified-id="Example-4.3-1.2.6.4.3">Example 4.3</a></span></li></ul></li><li><span><a href="#Part-5-(Histogram)" data-toc-modified-id="Part-5-(Histogram)-1.2.6.5">Part 5 (Histogram)</a></span><ul class="toc-item"><li><span><a href="#Example-5.1" data-toc-modified-id="Example-5.1-1.2.6.5.1">Example 5.1</a></span></li></ul></li><li><span><a href="#Part-6-(Pie-Chart)" data-toc-modified-id="Part-6-(Pie-Chart)-1.2.6.6">Part 6 (Pie Chart)</a></span><ul class="toc-item"><li><span><a href="#Example-6.1" data-toc-modified-id="Example-6.1-1.2.6.6.1">Example 6.1</a></span></li><li><span><a href="#Example-6.2" data-toc-modified-id="Example-6.2-1.2.6.6.2">Example 6.2</a></span></li></ul></li><li><span><a href="#Part-7-(Figure-Size)" data-toc-modified-id="Part-7-(Figure-Size)-1.2.6.7">Part 7 (Figure Size)</a></span><ul class="toc-item"><li><span><a href="#Problem-5" data-toc-modified-id="Problem-5-1.2.6.7.1">Problem 5</a></span></li><li><span><a href="#Problem-6" data-toc-modified-id="Problem-6-1.2.6.7.2">Problem 6</a></span></li></ul></li></ul></li><li><span><a href="#6.1.2.4-Advanced-Formatting" data-toc-modified-id="6.1.2.4-Advanced-Formatting-1.2.7">6.1.2.4 Advanced Formatting</a></span><ul class="toc-item"><li><span><a href="#Part-1-(Axis-Range)" data-toc-modified-id="Part-1-(Axis-Range)-1.2.7.1">Part 1 (Axis Range)</a></span><ul class="toc-item"><li><span><a href="#Example-1.1" data-toc-modified-id="Example-1.1-1.2.7.1.1">Example 1.1</a></span></li></ul></li><li><span><a href="#Part-2-(Log-Scale)" data-toc-modified-id="Part-2-(Log-Scale)-1.2.7.2">Part 2 (Log Scale)</a></span><ul class="toc-item"><li><span><a href="#Example-2.1" data-toc-modified-id="Example-2.1-1.2.7.2.1">Example 2.1</a></span></li><li><span><a href="#Example-2.2" data-toc-modified-id="Example-2.2-1.2.7.2.2">Example 2.2</a></span></li><li><span><a href="#Example-2.3" data-toc-modified-id="Example-2.3-1.2.7.2.3">Example 2.3</a></span></li></ul></li><li><span><a href="#Part-3-(Subplots)" data-toc-modified-id="Part-3-(Subplots)-1.2.7.3">Part 3 (Subplots)</a></span><ul class="toc-item"><li><span><a href="#Example-3.1" data-toc-modified-id="Example-3.1-1.2.7.3.1">Example 3.1</a></span></li><li><span><a href="#Example-3.2" data-toc-modified-id="Example-3.2-1.2.7.3.2">Example 3.2</a></span></li><li><span><a href="#Problem-7" data-toc-modified-id="Problem-7-1.2.7.3.3">Problem 7</a></span></li></ul></li><li><span><a href="#Part-4-(Removing-the-Axis)" data-toc-modified-id="Part-4-(Removing-the-Axis)-1.2.7.4">Part 4 (Removing the Axis)</a></span><ul class="toc-item"><li><span><a href="#Example-4.1" data-toc-modified-id="Example-4.1-1.2.7.4.1">Example 4.1</a></span></li></ul></li><li><span><a href="#Part-5-(Modifying-Defaults)" data-toc-modified-id="Part-5-(Modifying-Defaults)-1.2.7.5">Part 5 (Modifying Defaults)</a></span><ul class="toc-item"><li><span><a href="#Example-5.1-(Axis-Font-Size)" data-toc-modified-id="Example-5.1-(Axis-Font-Size)-1.2.7.5.1">Example 5.1 (Axis Font Size)</a></span></li></ul></li><li><span><a href="#Part-6-(Saving-Images)" data-toc-modified-id="Part-6-(Saving-Images)-1.2.7.6">Part 6 (Saving Images)</a></span><ul class="toc-item"><li><span><a href="#Example-6.1" data-toc-modified-id="Example-6.1-1.2.7.6.1">Example 6.1</a></span></li></ul></li><li><span><a href="#Part-7-(Including-Text)" data-toc-modified-id="Part-7-(Including-Text)-1.2.7.7">Part 7 (Including Text)</a></span><ul class="toc-item"><li><span><a href="#Example-7.1" data-toc-modified-id="Example-7.1-1.2.7.7.1">Example 7.1</a></span></li></ul></li><li><span><a href="#Part-8-(Including-Arrows)" data-toc-modified-id="Part-8-(Including-Arrows)-1.2.7.8">Part 8 (Including Arrows)</a></span><ul class="toc-item"><li><span><a href="#Example-8.1" data-toc-modified-id="Example-8.1-1.2.7.8.1">Example 8.1</a></span></li></ul></li><li><span><a href="#Part-9-(Annnotations)" data-toc-modified-id="Part-9-(Annnotations)-1.2.7.9">Part 9 (Annnotations)</a></span><ul class="toc-item"><li><span><a href="#Example-9.1" data-toc-modified-id="Example-9.1-1.2.7.9.1">Example 9.1</a></span></li><li><span><a href="#Problem-8" data-toc-modified-id="Problem-8-1.2.7.9.2">Problem 8</a></span></li></ul></li><li><span><a href="#Part-10-(Templates)" data-toc-modified-id="Part-10-(Templates)-1.2.7.10">Part 10 (Templates)</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Lecture 6
# ## Matplotlib

# %% [markdown]
# __Purpose:__
# The purpose of this lecture is to learn how to visualiza data in Python using a library called matplotlib. We will learn how to create charts that can be displayed within the Jupyter notebook, as well as customize the fonts, colors, etc.
#
# __At the end of this lecture you will be able to:__
# > 1. Understand how to create basic charts such as line charts, scatter plots, pie charts, histograms, etc.
# > 2. Customize the charts by manipulating the size, color, fonts, etc.
# > 3. Create multiple charts within one graph.
# > 4. Save the charts as an image.

# %% [markdown]
# ## 6.1 Matplotlib Introduction

# %% [markdown]
# ### 6.1.1 What is Matplotlib?

# %% [markdown]
# __Overview__
#
# Matplotlib is a library that allows visualization within Python.  You can generate line plots, scatter plots, histograms, bar charts, etc., with just a few lines of code.
#
# Matplotlib is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms. Matplotlib can be used in Python scripts, the Python and IPython shells, the Jupyter notebook, web application servers, and four graphical user interface toolkits.
#
# For simple plotting the pyplot module provides a MATLAB-like interface, particularly when combined with IPython. For the power user, you have full control of line styles, font properties, axes properties, etc, via an object oriented interface or via a set of functions familiar to MATLAB users.
#
# The [matplotlib.pyplot](https://matplotlib.org/api/pyplot_summary.html) module contains functions that allow you to generate many kinds of plots quickly.
#
# Matplotlib was originally written by John D. Hunter, has an active development community, and is distributed under a BSD-style license. Michael Droettboom was nominated as matplotlib's lead developer shortly before John Hunter's death in 2012, and further joined by Thomas Caswell.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# this statement allows the visuals to render within your Jupyter Notebook
# %matplotlib inline

# %% [markdown]
# ### 6.1.2 Matplotlib Basics

# %% [markdown]
# ### 6.1.2.1 Creating charts

# %% [markdown]
# ### Data Types
# Matplotlib accepts several types of data such as lists (as we previously showed), Numpy Arrays and Pandas Dataframes.

# %% [markdown]
# #### Part 1 (Data Types for Creating Charts in Matplotlib)

# %% [markdown]
# ##### Example 1.1 (Creating a line chart from a list)

# %% [markdown]
# As a starting point let's use a simple example by drawing a line chart from a list with the values 1, 2, 1, 3.

# %%
data_list = [1,2,1,3]
print(data_list, type(data_list))
plt.plot(data_list);
# Out:
# [1, 2, 1, 3] <class 'list'>

# %% [markdown]
# Note that the x-axis contains the index of the datapoint.  Remember that Python is 0 indexed.

# %%
x = [10,20, 21, 30]
plt.plot(x,data_list);

# %% [markdown]
# ##### Example 1.2 (Creating a line chart from a Numpy array)

# %% [markdown]
# Now we will create the same chart using a Numpy Array and a Pandas DataFrame.

# %%
data_numpy = np.array(data_list)
print(data_numpy, type(data_numpy))
plt.plot(data_numpy);
# Out:
# [1 2 1 3] <class 'numpy.ndarray'>

# %% [markdown]
# ##### Example 1.3 (Creating a line chart from a Pandas Series)

# %%
data_pandas_series = pd.Series(data_list)
print(data_pandas_series, type(data_pandas_series))
plt.plot(data_pandas_series);
# Out:
# 0    1
# 1    2
# 2    1
# 3    3
# dtype: int64 <class 'pandas.core.series.Series'>

# %% [markdown]
# ##### Example 1.4 (Creating a line chart from a Pandas DataFrame)

# %%
data_pandas = pd.DataFrame(data_list)
print(data_pandas, type(data_pandas))
plt.plot(data_pandas);
# Out:
#    0
# 0  1
# 1  2
# 2  1
# 3  3 <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### 6.1.2.2 Fomatting charts

# %% [markdown]
# #### Part 1 (Adding Titles)

# %% [markdown]
# We can also add a title to our figure using plt.title(), and we can modify the text properties.
# A full list of properties can be found here: https://matplotlib.org/users/text_props.html

# %% [markdown]
# ##### Example 1.1

# %%
plt.plot(data_list)
plt.title('First Plot');

# %%
plt.plot(data_list)
plt.title('Cursive Title',family='cursive',fontsize = 30,loc='left',color='r');

# %%
plt.plot(data_list)
plt.title('Boldly Hideous',fontsize = 40,style='italic',weight='bold',rotation=10,color='purple');

# %% [markdown]
# #### Part 2 (Adding X-Y Labels)

# %% [markdown]
# Similar to the title, we can also add labels in the $x$ and $y$ axis using plt.xlabel() and plt.ylabel().

# %% [markdown]
# ##### Example 2.1

# %%
plt.plot(data_list)
plt.xlabel('Label on the X axis')
plt.ylabel('Label on the Y axis',fontsize = 20, weight = 'bold',color='green');

# %% [markdown]
# ##### Problem 1
#
# Create a dataset that contains the values from 0 to 10 in increments of 0.01 for the $x$ value, and $sin(2*pi*x)$ for the $y$ value.
#
# **Hint:** Look at numpy for the function sin()

# %%
### Write the code here
pi = np.pi
x = np.arange(0, 10, 0.01)
wave_func = np.sin(2*pi*x)

plt.plot(x, wave_func)

# %% [markdown]
# ##### Problem 2
# Using the same dataset from the previous problem, create a line chart displaying $x$ versus $y$.  Include a title and labels for the $x$ and $y$ axis.  Play with the format of the text.

# %%
### Write the code here

plt.plot(x, wave_func, color = 'green', linestyle = 'dashed')

plt.title("Simple Wave Function", fontsize = 14, weight = 'bold', color = 'black')
plt.ylabel("y = sin( 2 * pi * x)", fontsize = 12, weight = 500, color = 'darkred')
plt.xlabel("x-values", fontsize = 12, weight = 500, color = 'blue')
# Out:
# Text(0.5,0,'x-values')

# %% [markdown]
# And for a little extra credit i'll do some research, indulge in something that has been a goal of mine, and plot an interactive graph using the `ipywidget` package. Shwing!

# %%
from ipywidgets import interact

def plot_sine(frequency=1.0, amplitude=1.0):
    plt.ylim(-1.0, 1.0);
    x = np.linspace(0, 10, 1000)
    plt.plot(x, amplitude*np.sin(x*frequency));
    plt.title("Interactive Sine Function", weight="bold")
    plt.grid()

interact(plot_sine, frequency=(0.5, 10.0), amplitude=(0.0, 1.0));

print("Oh Hello!")
# Out:
# interactive(children=(FloatSlider(value=1.0, description='frequency', max=10.0, min=0.5), FloatSlider(value=1.…
# Oh Hello!

# %% [markdown]
# #### Part 3 (Gridlines)

# %% [markdown]
# We can include gridlines with plt.grid()

# %% [markdown]
# ##### Example 3.1

# %%
plt.plot(data_list)
plt.grid()

# %% [markdown]
# ##### Example 3.2

# %% [markdown]
# We can also control the location of the ticks using plt.xticks() and plt.yticks()

# %%
plt.plot(data_list)
plt.grid()
ticks_x = np.linspace(0, 3, 10)
ticks_y = np.linspace(1, 3, 3)
plt.xticks(ticks_x)
plt.yticks(ticks_y);

# %% [markdown]
# ##### Example 3.3

# %% [markdown]
# Also, we can replace the text of the ticks.  Note that we can also modify the font!

# %%
plt.plot(data_list)
plt.grid()
ticks_x = np.linspace(0, 3, 4)
months = ['Jan','Feb','Mar','Apr']
plt.xticks(ticks_x, months, fontsize = '20', family = 'fantasy',color='orange');

# %% [markdown]
# Oh my doodles. Look at that!

# %% [markdown]
# ##### Problem 3
# Using the sine wave data set from the previous problem, create a line chart that contains grids.  In the $x$-axis we want 6 ticks at intervals of 2, i.e. 0, 2, 4 ..., 10.  On the $y$-axis we want two ticks, one at +1 and the other at -1 with the labels "Peak" and "Valley", respectively.

# %%
### Write the code here

plt.plot(x, wave_func)
plt.grid()
x_ticks = np.linspace(0,10,6)
y_ticks = np.linspace(-1,1,3)
plt.xticks(x_ticks)
plt.yticks(y_ticks, ["Valley", 0, "Peak"])
# Out:
# ([<matplotlib.axis.YTick at 0x10afa83c8>,
# ...
#  <a list of 3 Text yticklabel objects>)

# %% [markdown]
# #### Part 4 (Multiple Lines)
# You can have more than one line in a plot, by using the plt.plot() multiple times within the same cell.

# %% [markdown]
# ##### Example 4.1

# %%
data_list = [1,2,1,3]
data_list_2 = [3, 2.3, 2, 0]
plt.plot(data_list)
plt.plot(data_list_2);

# %% [markdown]
# #### Part 5 (Legends)

# %% [markdown]
# Legends can be added to label each line with plt.legend().

# %% [markdown]
# ##### Example 5.1

# %%
plt.plot(data_list)
plt.plot(data_list_2)
plt.legend(['First Line','Second Line'],shadow = True, loc = 0);

# %% [markdown]
# #### Part 6 (Color)

# %% [markdown]
# The same way we have modified the color of the font, we can modify the color of the line.
# > **Alias:** For alias colors check here: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.colors.html
#
# > **Name:** For name color information check here: https://www.w3schools.com/cssref/css_colors.asp
#
# > **Hexadecimal:** The color can be represented in hexadecimal (https://en.wikipedia.org/wiki/Hexadecimal).  Every color has three components: Red, Green and Blue, aka RGB.  Each components can have a value between 0 and 255 (00 to FF in hexadecimal).  So if you want the color #3FEF0A (note that the # indicates hexadecimal), you are assigning a value of 3F to Red, EF to Green and 0A to Blue.

# %% [markdown]
# ##### Example 6.1: Color with alias

# %%
plt.plot(data_list, 'g');

# %%
plt.plot(data_list, c='g');

# %%
plt.plot(data_list, color = 'g');

# %% [markdown]
# ##### Example 6.2: Color with Name
# https://www.w3schools.com/cssref/css_colors.asp

# %%
plt.plot(data_list, c = 'Aqua');

# %% [markdown]
# ##### Example 6.3: Color with RGB Hexadecimal
# The color needs three values for the Red, Green and Blue channel.  Each channel can have a value between 0 and 255.  You can use the function $hex()$ to convert a decimal to hexadecimal.

# %%
print('The decimal {} is {} in hexadecimal'.format(0,hex(0)))
print('The decimal {} is {} in hexadecimal'.format(128,hex(128)))
print('The decimal {} is {} in hexadecimal'.format(36,hex(36)))
print('The decimal {} is {} in hexadecimal'.format(198,hex(198)))
print('The decimal {} is {} in hexadecimal'.format(255,hex(255)))
# Out:
# The decimal 0 is 0x0 in hexadecimal
# The decimal 128 is 0x80 in hexadecimal
# The decimal 36 is 0x24 in hexadecimal
# The decimal 198 is 0xc6 in hexadecimal
# The decimal 255 is 0xff in hexadecimal

# %%
plt.plot(data_list, c = '#00FFFF');

# %% [markdown]
# #### Part 7 (Line Width)

# %% [markdown]
# The linewidth of the chart can also be modified, with the linewidth parameter.

# %% [markdown]
# ##### Example 7.1

# %%
plt.plot(data_list, linewidth = 10)
plt.plot(data_list_2, linewidth = 1);

# %% [markdown]
# #### Part 8 (Line Style)

# %% [markdown]
# Lines come in several types, such as solid, dashed, and so on.  They can be modified with the linestyle parameter.  You can find the styles here: https://matplotlib.org/gallery/lines_bars_and_markers/line_styles_reference.html

# %% [markdown]
# ##### Example 8.1

# %%
plt.plot(data_list, linestyle = '--',linewidth = 3, c = 'b')
plt.plot(data_list_2, linestyle = '-.',linewidth = 5, c = 'r') 
plt.plot(np.array(data_list_2)+1, linestyle = ':',linewidth = 2, c = 'k')
plt.plot(np.array(data_list)-1, linestyle = '-',linewidth = 4, c ='g');

# %% [markdown]
# ##### Problem 4
# Create a dataset that contains $2*cos(pi*x)$ for the $y2$ value.  Plot $x$ versus the $y$ and $y2$ values on the same chart.  Assign unique linewidth, color, and style to each line.  Make sure to include a legend.

# %%
### Write the code here
x = np.arange(0, 10, 0.01)
y = 2*(np.sin(pi*x))
y2 = 2*(np.cos(pi*x))

plt.plot(x, y, linewidth = 3, linestyle = '--', c = "lightblue")
plt.plot(x, y2, linewidth = 2, c = "orange")
plt.legend(['2*(np.sin(pi*x))','2*(np.cos(pi*x))'],shadow = True, loc = 0);

# %% [markdown]
# ### 6.1.2.3 Types of Charts

# %% [markdown]
# There are a wide range of visuals we can create.  In this section we will cover the basics.

# %% [markdown]
# #### Part 1 (Line Charts)

# %% [markdown]
# ##### Example 1.1

# %%
new_x = np.arange(100)
new_y = np.random.randint(0,10,100) # random integer number between 0 and 9 (10 is excluded)
plt.plot(new_x,new_y);

# %% [markdown]
# #### Part 2 (Bar Chart)

# %% [markdown]
# ##### Example 2.1

# %%
new_x = np.arange(20)
new_y = np.random.randint(5,10,20)
plt.bar(new_x,new_y);

# %% [markdown]
# #### Part 3 (Error Bars)

# %% [markdown]
# These plots are commonly used to plot distribution of errors.

# %% [markdown]
# ##### Example 3.1

# %%
new_x = np.arange(1, 5, 1)
new_y = new_x**1.5

# example variable error bar values
yerr = np.sqrt(new_x)

plt.bar(new_x,new_y)
plt.errorbar(new_x, new_y,fmt='r.', yerr=yerr);

# %% [markdown]
# #### Part 4 (Scatter Plot)

# %% [markdown]
# ##### Example 4.1

# %%
new_x = np.random.randn(1000)
new_y = np.random.randn(1000)
plt.scatter(new_x,new_y);

# %% [markdown]
# ##### Example 4.2

# %% [markdown]
# Note that a lot of dots overlap in the middle.  We can play with the transparency of the color to see how the dots overlap by modifying a parameter called alpha between 0 and 1.

# %%
plt.scatter(new_x,new_y,alpha = 0.2);

# %% [markdown]
# ##### Example 4.3

# %% [markdown]
# Similarly we can modify the type of the marker (https://matplotlib.org/api/markers_api.html) and its size.

# %%
plt.scatter(new_x,new_y,marker = '+',s = 100);

# %% [markdown]
# #### Part 5 (Histogram)

# %% [markdown]
# ##### Example 5.1

# %%
new_x = np.random.randn(100000)
plt.hist(new_x,100);

# %% [markdown]
# #### Part 6 (Pie Chart)

# %% [markdown]
# ##### Example 6.1

# %%
new_x = np.arange(1,4)
plt.pie(new_x,labels=['a','b','c']);

# %% [markdown]
# ##### Example 6.2

# %%
plt.pie(new_x,labels=['a','b','c'],explode = [.1,.2,0]);

# %% [markdown]
# #### Part 7 (Figure Size)
#
# The Pie Chart above does not look like a circle.  This is because the default size of a figure is 8 (width) x 6 (height).  We can modify this using the "figure" parameter "figsize".

# %%
plt.figure(figsize = [5,5]) # [width, height]
plt.pie(new_x,labels=new_x);

# %% [markdown]
# ##### Problem 5
# Using the same dataset from the previous problem, create a histogram of variable $y$, and use 15 bins.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# this statement allows the visuals to render within your Jupyter Notebook
# %matplotlib inline

# %%
### Write the code here
plt.hist(y, 15)
# Out:
# (array([165.,  70.,  60.,  50.,  50.,  40.,  40.,  50.,  40.,  40.,  50.,
#          50.,  60.,  70., 165.]),
#  array([-2.        , -1.73333333, -1.46666667, -1.2       , -0.93333333,
#         -0.66666667, -0.4       , -0.13333333,  0.13333333,  0.4       ,
#          0.66666667,  0.93333333,  1.2       ,  1.46666667,  1.73333333,
#          2.        ]),
#  <a list of 15 Patch objects>)

# %% [markdown]
# ##### Problem 6
# Create a scatter plot of $y2$ versus $y$.  Modify the figure size, the marker type and size, and the transparency.

# %%
### Write the code here
plt.figure( figsize = [5, 5])
plt.scatter(np.tanh(y), np.sinh(y2), c = 'orange', alpha = 0.1, marker = 'o', s = 295)
plt.scatter(np.tanh(y), np.sinh(y2), c = 'b', alpha = 0.05, marker = '.', s = 295)

# %% [markdown]
# ### 6.1.2.4 Advanced Formatting

# %% [markdown]
# #### Part 1 (Axis Range)

# %% [markdown]
# We can also modify the range of the axis by using plt.axis([x_min, x_max, y_min, y_max]).

# %% [markdown]
# ##### Example 1.1

# %%
new_x = np.arange(100)
new_y = np.random.randint(0,10,100)
plt.plot(new_x,new_y)
plt.axis([-10, 110, -10, 20]); # [x_min, x_max, y_min, y_max]

# %% [markdown]
# #### Part 2 (Log Scale)

# %% [markdown]
# Let's look at an example where the data set covers several orders of magnitude ($e^{x}$).  When we plot the data in a linear scale, we lose some details.

# %% [markdown]
# ##### Example 2.1

# %%
new_x = np.arange(8)
new_y = np.e**new_x
plt.plot(new_x,new_y)
plt.scatter(new_x,new_y);

# %% [markdown]
# A solution is to plot the log transform of the data.

# %%
plt.plot(new_x,np.log10(new_y)); # This places the points on the graph
plt.scatter(new_x,np.log10(new_y)); # This places the line on the graph

# %% [markdown]
# An alternative is to ask the plotting function to display in a log scale.

# %%
plt.semilogy(new_x, new_y, c='r')
plt.semilogy(new_x, new_y, '+', ms=25, c='b'); #it is in log10
plt.grid(True, which = 'major', axis = 'x') # try which = 'minor' to see minor vs major grid lines

# %% [markdown]
# Observe that the y-axis displays the log values when you use semilogy().  Similarly we can plot the x-axis as a log scale (semilogx), and both axis as a log scale (loglog).

# %% [markdown]
# ##### Example 2.2

# %%
plt.semilogx(new_x,new_y,c='r')
plt.semilogx(new_x,new_y,'.',ms=15,c='r'); #it is in log10

# %%
plt.plot(new_x,new_y)
plt.plot(new_x,new_y,'.',ms=15,c='r')

# %% [markdown]
# ##### Example 2.3

# %%
plt.loglog(new_x,new_y,c='r')
plt.loglog(new_x,new_y,'.',ms=15,c='r'); #it is in log10

# %% [markdown]
# #### Part 3 (Subplots)

# %% [markdown]
# Sometimes we want to create multiple plots together.  We can use plt.subplots(number of rows, number of columns, number of the plot).

# %% [markdown]
# ##### Example 3.1

# %%
new_x = np.arange(20)
new_y = np.random.randint(5,10,20)

plt.figure(figsize=[15,5])

plt.suptitle('Main Title',fontsize = 16)

plt.subplot(1,2,1) # (number of rows, number of columns, number of plot)
plt.plot(new_x,new_y)
plt.title('Line Chart')

plt.subplot(1,2,2)
plt.bar(new_x,new_y)
plt.title('Bar Chart');

# %% [markdown]
# ##### Example 3.2

# %%
new_x = np.arange(20)
new_y = np.random.randint(5,10,20)

plt.figure(figsize=[15,7])

plt.suptitle('Main Title',fontsize = 16)

plt.subplot(2,1,1) # (number of rows, number of columns, number of plot)
plt.plot(new_x,new_y)
plt.title('Line Chart')

plt.subplot(2,1,2)
plt.bar(new_x,new_y)
plt.title('Bar Chart');

# %% [markdown]
# ##### Problem 7
# Create a set of 4 plots in 2 rows and 2 columns.  The plots should contain:
#
# 1) Top Left: Line Plot of $x$ versus $y$. Make the axis range from -3 to 13 in the x-axis, and -3 to 3 in the y-axis.
#
# 2) Top Right: Plot of $y2$ using a dashed line.
#
# 3) Bottom Left: Scatter Plot of $y$ versus $y^2$. With a title of 'y-squared'.
#
# 4) Bottom Right: Scatter Plot of $y$ versus $y^2$ using log scale on the y-axis.

# %%
### Write the code here
plt.figure(figsize=[15,7])

plt.suptitle('Main Title: Problem 7', fontsize = 18)

plt.subplot(2, 2, 1)
plt.plot(x, y)
plt.ylim([-3, 13])
plt.xlim([-3, 13])
plt.title('x vs y')

plt.subplot(2, 2, 2)
plt.plot(y2, linestyle = '--')
plt.title('y2')

plt.subplot(2, 2, 3)
plt.plot(y, y**2)
plt.title('y-squared')

plt.subplot(2, 2, 4)
#plt.plot(y, y**2)
plt.semilogy(y,y**2)
plt.title('y vs y^2 (log scale)')
# Out:
# Text(0.5,1,'y vs y^2 (log scale)')

# %% [markdown]
# #### Part 4 (Removing the Axis)

# %% [markdown]
# In some cases we may prefer to hide the axis with plt.axis().

# %% [markdown]
# ##### Example 4.1

# %%
new_x = np.arange(100)
new_y = np.random.randint(0,10,100)

plt.figure(figsize=[15,5])

plt.subplot(1,2,1)
plt.plot(new_x,new_y)

plt.subplot(1,2,2)
plt.plot(new_x,new_y)
plt.axis('off');

# %% [markdown]
# #### Part 5 (Modifying Defaults)

# %% [markdown]
# ##### Example 5.1 (Axis Font Size)

# %%
#help(plt.rc)

# %%
new_x = np.arange(100)
new_y = np.random.randint(0,10,100)

plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=10) 

plt.plot(new_x,new_y);

# %% [markdown]
# #### Part 6 (Saving Images)

# %% [markdown]
# Images can be exported into other formats so they can later be included into reports or slideshows.
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.savefig.html

# %% [markdown]
# ##### Example 6.1

# %%
new_x = np.arange(100)
new_y = np.random.randint(0,10,100)
plt.plot(new_x,new_y)

plt.savefig('testplot.png')

# %% [markdown]
# __We can display the image in the following way:__

# %%
from IPython.display import Image
print(Image(filename='testplot.png'))
Image(filename='testplot.png')
# Out:
# <IPython.core.display.Image object>

# %% [markdown]
# __Or, if we want to construct a display of multiple images we can use a loop:__

# %%
# First let's create and save a second graph...
new_x = np.arange(100)
new_y = np.sin(new_x)
plt.plot(new_x,new_y)

plt.savefig('testplot2.png')

# %%
# Then we import the display feature and wrap the construction in a for loop:

from IPython.display import display

listOfImageNames = ['testplot.png',
                    'testplot2.png']

for imageName in listOfImageNames:
    display(Image(filename=imageName))

# %% [markdown]
# #### Part 7 (Including Text)

# %% [markdown]
# ##### Example 7.1

# %%
new_x = np.arange(100)
new_y = np.random.randint(0,10,100)+(0.05*new_x)**2
plt.plot(new_x,new_y)
plt.text(60,5,'Sample Text',fontsize = 20,backgroundcolor = 'k',color = 'white'); # x and y position of start of text

# %% [markdown]
# #### Part 8 (Including Arrows)

# %% [markdown]
# ##### Example 8.1

# %%
plt.plot(new_x,new_y)
plt.arrow(18,25,15,-10,width=0.5,head_width=3,color='orange'); # x and y of starting, delta_x and delta_y

# %% [markdown]
# #### Part 9 (Annnotations)
# https://matplotlib.org/users/annotations_intro.html

# %% [markdown]
# ##### Example 9.1

# %%
plt.plot(new_x,new_y)
plt.annotate('Main Point', xy=(40, 12), xytext=(5, 25),
             arrowprops=dict(facecolor='red',shrink = 0.1),fontsize = 15);

# xy is x and y location of the arrow head
# xytext is x and y location of the start of the text

# %% [markdown]
# ##### Problem 8
# Plot the $x$ versus $y$ sine wave.
#
# 1) Make an annotation on the first peak,
#
# 3) Add a text somewhere in the middle of the image
#
# Make sure to format the text, colors, etc.

# %%
### Write the code here

plt.plot(x, y)
plt.text(7.5, -1.8, 'Some Text', backgroundcolor = 'white', fontweight = '600', fontsize = '13')
plt.annotate('First Peak, Local Maximum', xy = (x[y.argmax()], y[y.argmax()]), xytext = (2.5, 1.8),
            arrowprops = dict(facecolor = 'blue', shrink = 0.1), fontsize = 11,
            backgroundcolor = 'lightgrey')
# Out:
# Text(2.5,1.8,'First Peak, Local Maximum')

# %% [markdown]
# #### Part 10 (Templates)
# There are many design templates.  Here we presents the xkcd (https://www.xkcd.com/373/) template.

# %%
with plt.xkcd():
    plt.plot(new_x,new_y)
    plt.xlabel('X Axis')
